# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_train_df = pd.read_csv('train.csv')
titanic_test_df = pd.read_csv('test.csv')

# %%
print(titanic_test_df.shape)
print(titanic_train_df.shape)
# Out:
# (418, 11)
# (891, 12)

# %%
(titanic_train_df.head(20))
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic_train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(titanic_test_df.dtypes)
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# cleaning data

# %%
#looking for null values

# %%
titanic_train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_train_df['Cabin'].values
# Out:
# array([nan, 'C85', nan, 'C123', nan, nan, 'E46', nan, nan, nan, 'G6',
#        'C103', nan, nan, nan, nan, nan, nan, nan, nan, nan, 'D56', nan,
#        'A6', nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'B78', nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'D33', nan, 'B30', 'C52', nan, nan, nan,
#        nan, nan, 'B28', 'C83', nan, nan, nan, 'F33', nan, nan, nan, nan,
#        nan, nan, nan, nan, 'F G73', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'E31', nan,
#        nan, nan, 'A5', 'D10 D12', nan, nan, nan, nan, 'D26', nan, nan,
#        nan, nan, nan, nan, nan, 'C110', nan, nan, nan, nan, nan, nan, nan,
#        'B58 B60', nan, nan, nan, nan, 'E101', 'D26', nan, nan, nan,
#        'F E69', nan, nan, nan, nan, nan, nan, nan, 'D47', 'C123', nan,
#        'B86', nan, nan, nan, nan, nan, nan, nan, nan, 'F2', nan, nan,
# ...

# %%
titanic_train_df['Cabin'].str.contains('None')
# Out:
# 0        NaN
# 1      False
# 2        NaN
# 3      False
# 4        NaN
#        ...
# 886      NaN
# 887    False
# 888      NaN
# 889    False
# 890      NaN
# Name: Cabin, Length: 891, dtype: object

# %%
# regular expression way

# %%
# import re
# for i in range(titanic_train_df['Cabin'].shape[0]):
#     if pd.notna(titanic_train_df['Cabin'].values[i]):
#         match = re.match(r"([A-Za-z])" ,str(titanic_train_df['Cabin'].values[i]) )
#         if match:
#             titanic_train_df['Cabin'].values[i] = match.group(1)

#     else :
#         titanic_train_df['Cabin'].values[i] = "unknown"   
# titanic_train_df['Cabin'].unique()

# %%
# slicing way

# %%
titanic_train_df['Cabin'] = titanic_train_df['Cabin'].str[0]
titanic_train_df['Cabin']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
for i in range(titanic_train_df['Cabin'].shape[0]):
    if not pd.notna(titanic_train_df['Cabin'].values[i]):
         titanic_train_df['Cabin'].values[i] = "unknown"   
titanic_train_df['Cabin'].unique()
# Out:
# array(['unknown', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
survived = titanic_train_df.groupby(titanic_train_df['Cabin'])['Survived'].sum()

# %%
total = titanic_train_df.groupby(titanic_train_df['Cabin'])['Survived'].count()

# %%
survived_cabin_df = pd.DataFrame({
            'Total' : total,
            'Survived' : survived
})

# %%
survived_cabin_df['Died'] = survived_cabin_df['Total'] - survived_cabin_df['Survived']

# %%
survived_cabin_df
# Out:
#          Total  Survived  Died
# Cabin
# A           15         7     8
# B           47        35    12
# C           59        35    24
# D           33        25     8
# E           32        24     8
# F           13         8     5
# G            4         2     2
# T            1         0     1
# unknown    687       206   481

# %%
survived_cabin_df['died_percent'] = (survived_cabin_df['Died']/survived_cabin_df['Total'])*100

# %%
survived_cabin_df
# Out:
#          Total  Survived  Died  died_percent
# Cabin
# A           15         7     8     53.333333
# B           47        35    12     25.531915
# C           59        35    24     40.677966
# D           33        25     8     24.242424
# E           32        24     8     25.000000
# F           13         8     5     38.461538
# G            4         2     2     50.000000
# T            1         0     1    100.000000
# unknown    687       206   481     70.014556

# %%
# we cant get a clear undertanding from cabin column so we will drop it

# %%
titanic_train_df.drop('Cabin', axis=1, inplace=True)
titanic_test_df.drop('Cabin', axis=1, inplace=True)

# %%
titanic_train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# in age column we have 177 na values outof 891 values so we are goin to fill this na with mean or median

# %%
age_df = titanic_train_df['Age'].dropna()

# %%
size_age_df = age_df.shape[0]
size_age_df
# Out:
# 714

# %%
# looking for shape of age column

# %%
counts , bin_edges = np.histogram(age_df , bins=int(np.sqrt(size_age_df)))

# %%
mid_points_age_bin = 0.5*(bin_edges[:-1] + bin_edges[1:])

# %%
sns.histplot(age_df, bins=int(np.sqrt(size_age_df)), kde=True, color="red")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
age_df.skew()
# Out:
# np.float64(0.38910778230082693)

# %% [markdown]
# Skewness ≈ 0 → distribution is symmetric (like normal).  Use mean
#
# |Skewness| < 0.5 → fairly symmetric → mean is okay
#
# 0.5 ≤ |Skewness| < 1 → moderate skew → consider median
#
# |Skewness| ≥ 1 → highly skewed → median (or log-transform first)

# %%
#apply mean of the age column to the na values

# %%
titanic_train_df['Age'].fillna(titanic_train_df['Age'].mean(), inplace=True)
# Out:
# C:\Users\KALINDU RANATHUNGA\AppData\Local\Temp\ipykernel_12792\138837898.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_train_df['Age'].fillna(titanic_train_df['Age'].mean(), inplace=True)

# %%
titanic_train_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
for i in range(titanic_train_df['Embarked'].shape[0]):
    if not pd.notna(titanic_train_df['Embarked'][i]):
        print(titanic_train_df.loc[i] , "\n")
# Out:
# PassengerId                     62
# Survived                         1
# Pclass                           1
# Name           Icard, Miss. Amelie
# Sex                         female
# Age                           38.0
# SibSp                            0
# Parch                            0
# Ticket                      113572
# Fare                          80.0
# Embarked                       NaN
# Name: 61, dtype: object
#
# PassengerId                                          830
# Survived                                               1
# Pclass                                                 1
# Name           Stone, Mrs. George Nelson (Martha Evelyn)
# Sex                                               female
# Age                                                 62.0
# SibSp                                                  0
# Parch                                                  0
# Ticket                                            113572
# ...

# %%
# remove those null values in Embarked column

# %%
titanic_train_df.dropna(subset=['Embarked'], inplace=True)

# %%
titanic_train_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic_train_df['Age'] = titanic_train_df['Age'].astype('int')

# %%
titanic_train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
# null value cleaning complete

# %%
# checking fro duplicates

# %%
titanic_train_df.duplicated().unique()
# Out:
# array([False])

# %%
#so there are any duplicates row wise

# %%
titanic_train_df.duplicated(subset='PassengerId').unique()
# Out:
# array([False])

# %%
titanic_train_df.duplicated(subset='Name').unique()
# Out:
# array([False])

# %%
# no duplcates found

# %%
# handling outliers 
# checking outlier in age and fare columns

# %%
sns.boxplot(titanic_train_df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# seems like lots of people are under 50. So we acnr take elder ages as outliers

# %%
sns.boxplot(titanic_train_df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
fare_df = titanic_train_df['Fare']
size_fare_df = fare_df.shape[0]
size_fare_df
# Out:
# 889

# %%
sns.histplot(fare_df, bins=int(np.sqrt(size_fare_df)), kde=True, color="red")
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# fare is higherly positively skewed but it is the nature of actual data we acnt change that

# %%
# Standadizing and Normalizing

# %%
# get male female into 1,0

# %%
titanic_train_df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 889, dtype: object

# %%
titanic_train_df['Sex'] = titanic_train_df['Sex'].map({'male':1 , 'female':0})

# %%
titanic_train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1
# 2                               Heikkinen, Miss. Laina    0   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1
# 4                             Allen, Mr. William Henry    1   35      0
# ..                                                 ...  ...  ...    ...
# ...

# %%
# do onehot encoding for dataframe

# %%
titanic_train_df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
embarked_dumies = pd.get_dummies(titanic_train_df['Embarked'] , prefix='Embarked')
embarked_dumies
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 0         False       False        True
# 1          True       False       False
# 2         False       False        True
# 3         False       False        True
# 4         False       False        True
# ..          ...         ...         ...
# 886       False       False        True
# 887       False       False        True
# 888       False       False        True
# 889        True       False       False
# 890       False        True       False
#
# [889 rows x 3 columns]

# %%
titanic_train_df = pd.concat([titanic_train_df,embarked_dumies] , axis=1)

# %%
titanic_train_df.drop('Embarked' , axis=1 , inplace=True)

# %%
titanic_train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked_C        bool
# Embarked_Q        bool
# Embarked_S        bool
# dtype: object

# %%
# feature engineering

# %%
titanic_train_df.drop('Name' , axis=1 , inplace=True)

# %%
titanic_train_df['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 889, dtype: object

# %%
titanic_train_df.groupby('Ticket')['Ticket'].count()
# Out:
# Ticket
# 110152         3
# 110413         3
# 110465         2
# 110564         1
# 110813         1
#               ..
# W./C. 6608     4
# W./C. 6609     1
# W.E.P. 5734    1
# W/C 14208      1
# WE/P 5735      2
# Name: Ticket, Length: 680, dtype: int64

# %%
# this means there are some groups who are use same ticket beacuse they went as a team

# %%
titanic_train_df['group_help_coef'] = titanic_train_df.groupby('Ticket')['Ticket'].transform('count')
titanic_train_df.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    1   22      1      0         A/5 21171
# 1             2         1       1    0   38      1      0          PC 17599
# 2             3         1       3    0   26      0      0  STON/O2. 3101282
# 3             4         1       1    0   35      1      0            113803
# 4             5         0       3    1   35      0      0            373450
# 5             6         0       3    1   29      0      0            330877
# 6             7         0       1    1   54      0      0             17463
# 7             8         0       3    1    2      3      1            349909
# 8             9         1       3    0   27      0      2            347742
# 9            10         1       2    0   14      1      0            237736
# 10           11         1       3    0    4      1      1           PP 9549
# ...

# %%
titanic_train_df.drop('Ticket' , axis=1 , inplace=True)

# %%
titanic_train_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch     Fare  \
# 0             1         0       3    1   22      1      0   7.2500
# 1             2         1       1    0   38      1      0  71.2833
# 2             3         1       3    0   26      0      0   7.9250
# 3             4         1       1    0   35      1      0  53.1000
# 4             5         0       3    1   35      0      0   8.0500
# 5             6         0       3    1   29      0      0   8.4583
# 6             7         0       1    1   54      0      0  51.8625
# 7             8         0       3    1    2      3      1  21.0750
# 8             9         1       3    0   27      0      2  11.1333
# 9            10         1       2    0   14      1      0  30.0708
# 10           11         1       3    0    4      1      1  16.7000
# 11           12         1       1    0   58      0      0  26.5500
# 12           13         0       3    1   20      0      0   8.0500
# ...

# %%
coorelations = titanic_train_df.corr()

# %%
coorelations['Survived']
# Out:
# PassengerId       -0.005028
# Survived           1.000000
# Pclass            -0.335549
# Sex               -0.541585
# Age               -0.072695
# SibSp             -0.034040
# Parch              0.083151
# Fare               0.255290
# Embarked_C         0.169966
# Embarked_Q         0.004536
# Embarked_S        -0.151777
# group_help_coef    0.037872
# Name: Survived, dtype: float64

# %%
titanic_train_df.drop('Parch', axis=1 , inplace=True )

# %%
titanic_train_df.drop('SibSp' , axis=1 ,inplace=True )

# %%
titanic_train_df.drop('PassengerId' , axis=1 , inplace=True)

# %%
titanic_train_df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'Embarked_C', 'Embarked_Q',
#        'Embarked_S', 'group_help_coef'],
#       dtype='object')

# %%
titanic_train_df
# Out:
#      Survived  Pclass  Sex  Age     Fare  Embarked_C  Embarked_Q  Embarked_S  \
# 0           0       3    1   22   7.2500       False       False        True
# 1           1       1    0   38  71.2833        True       False       False
# 2           1       3    0   26   7.9250       False       False        True
# 3           1       1    0   35  53.1000       False       False        True
# 4           0       3    1   35   8.0500       False       False        True
# ..        ...     ...  ...  ...      ...         ...         ...         ...
# 886         0       2    1   27  13.0000       False       False        True
# 887         1       1    0   19  30.0000       False       False        True
# 888         0       3    0   29  23.4500       False       False        True
# 889         1       1    1   26  30.0000        True       False       False
# 890         0       3    1   32   7.7500       False        True       False
#
#      group_help_coef
# 0                  1
# ...

# %%
# now dataset is ready

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier

# %%
X = titanic_train_df.drop('Survived', axis=1)  # no inplace
y = titanic_train_df['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y ,random_state=42)

# %%
LogisticRegression_model = LogisticRegression(max_iter=1000)

# %%
LogisticRegression_model.fit(X_train , y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = LogisticRegression_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7921348314606742
# Confusion Matrix:
#  [[94 16]
#  [21 47]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       110
#            1       0.75      0.69      0.72        68
#
#     accuracy                           0.79       178
#    macro avg       0.78      0.77      0.78       178
# weighted avg       0.79      0.79      0.79       178

# %%
LogisticRegression_model.coef_
# Out:
# array([[-1.03682890e+00, -2.48676231e+00, -3.39831750e-02,
#          2.45190208e-03, -9.37482526e-03,  3.48607160e-01,
#         -3.40878844e-01, -1.27133839e-01]])

# %%
KNN_model = KNeighborsClassifier(n_neighbors=2)

# %%
KNN_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred_2 = KNN_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred_2))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_2))
print("Classification Report:\n", classification_report(y_test, y_pred_2))
# Out:
# Accuracy: 0.6685393258426966
# Confusion Matrix:
#  [[98 12]
#  [47 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.89      0.77       110
#            1       0.64      0.31      0.42        68
#
#     accuracy                           0.67       178
#    macro avg       0.66      0.60      0.59       178
# weighted avg       0.66      0.67      0.63       178
